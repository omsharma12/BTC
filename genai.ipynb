# %% [markdown]
# <a href="https://colab.research.google.com/github/omsharma12/BTC/blob/main/genai.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget "https://drive.google.com/uc?export=download&id=1tqSMhX1MRd5I1hXTaNuR2ZS-uDdMWTRG" -O amazon_products.csv
# Out:
# --2025-05-08 13:51:55--  https://drive.google.com/uc?export=download&id=1tqSMhX1MRd5I1hXTaNuR2ZS-uDdMWTRG
# Resolving drive.google.com (drive.google.com)... 172.217.7.46, 2607:f8b0:4025:815::200e
# Connecting to drive.google.com (drive.google.com)|172.217.7.46|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1tqSMhX1MRd5I1hXTaNuR2ZS-uDdMWTRG&export=download [following]
# --2025-05-08 13:51:55--  https://drive.usercontent.google.com/download?id=1tqSMhX1MRd5I1hXTaNuR2ZS-uDdMWTRG&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.250.65.97, 2607:f8b0:4025:804::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.250.65.97|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19578629 (19M) [application/octet-stream]
# Saving to: ‘amazon_products.csv’
#
# ...

# %%
import pandas as pd
df = pd.read_csv('amazon_products.csv')
df.head()
# Out:
#                                                TITLE  \
# 0    SG LEMAN Mens Kurta Set (UP-31165_Navy Blue_42)
# 1         Gorilla 6200022-6 Wood Glue (6 Pack), 8 oz
# 2  WHITBULL Double Mobile Leather Anti Theft Cell...
# 3  Riderz Lord Shiva in Dhyana Mudra Idol, Medium...
# 4      SPYRA SpyraBase Blue - Tactical SpyraTwo Gear
#
#                                          DESCRIPTION
# 0  SG LEMAN presenting here the latest designer K...
# 1  Gorilla Wood Glue is the adhesive that woodwor...
# 2  This is a Universal Long Lasting Leather Carry...
# 3  Material: POLIEAZIN FIBER| Package Contents: 1...
# 4  Well, imagine you are having a water fight and...

# %%
# !pip install chromadb PyPDF2 sentence_transformers langchain-community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 25.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 4.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.0 MB/s eta 0:00:00
# ...

# %%
from langchain_community.document_loaders import CSVLoader

loader = CSVLoader(file_path = '/content/amazon_products.csv', source_column = 'DESCRIPTION', autodetect_encoding=True)
docs = loader.load()

# %%
len(docs)
# Out:
# 20000
